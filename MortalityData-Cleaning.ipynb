# %%
#Import Dependencies
import pandas as pd

# %%
#Import Wonder Data, and add to DataFrame
mortality_df = pd.read_csv('Desktop/2016Mortality.txt', sep="\t")
mortality_df.head(10)
# Out:
#   Notes               County  County Code  Deaths  Population Crude Rate
# 0   NaN   Autauga County, AL       1001.0   520.0     55416.0      938.4
# 1   NaN   Baldwin County, AL       1003.0  1974.0    208563.0      946.5
# 2   NaN   Barbour County, AL       1005.0   256.0     25965.0      985.9
# 3   NaN      Bibb County, AL       1007.0   239.0     22643.0     1055.5
# 4   NaN    Blount County, AL       1009.0   697.0     57704.0     1207.9
# 5   NaN   Bullock County, AL       1011.0   133.0     10362.0     1283.5
# 6   NaN    Butler County, AL       1013.0   275.0     19998.0     1375.1
# 7   NaN   Calhoun County, AL       1015.0  1404.0    114611.0     1225.0
# 8   NaN  Chambers County, AL       1017.0   460.0     33843.0     1359.2
# 9   NaN  Cherokee County, AL       1019.0   361.0     25725.0     1403.3

# %%
#Transform DataFrame to show columns of interest - remove crude rate and notes, divide deaths/population per 1000
mortality_df = mortality_df[['County', 'County Code', 'Deaths', 'Population']]
mortality_df['Death Rate per 1000'] = (mortality_df['Deaths']/mortality_df['Population'] * 1000).round(1)
mortality_df.head(10)
# Out:
#                 County  County Code  Deaths  Population  Death Rate per 1000
# 0   Autauga County, AL       1001.0   520.0     55416.0                  9.4
# 1   Baldwin County, AL       1003.0  1974.0    208563.0                  9.5
# 2   Barbour County, AL       1005.0   256.0     25965.0                  9.9
# 3      Bibb County, AL       1007.0   239.0     22643.0                 10.6
# 4    Blount County, AL       1009.0   697.0     57704.0                 12.1
# 5   Bullock County, AL       1011.0   133.0     10362.0                 12.8
# 6    Butler County, AL       1013.0   275.0     19998.0                 13.8
# 7   Calhoun County, AL       1015.0  1404.0    114611.0                 12.3
# 8  Chambers County, AL       1017.0   460.0     33843.0                 13.6
# 9  Cherokee County, AL       1019.0   361.0     25725.0                 14.0

# %%
mortality_df.style.format({
    'County Code': '{:.0f}'.format,
})
mortality_df.head()
# Out:
#                County  County Code  Deaths  Population  Death Rate per 1000
# 0  Autauga County, AL       1001.0   520.0     55416.0                  9.4
# 1  Baldwin County, AL       1003.0  1974.0    208563.0                  9.5
# 2  Barbour County, AL       1005.0   256.0     25965.0                  9.9
# 3     Bibb County, AL       1007.0   239.0     22643.0                 10.6
# 4   Blount County, AL       1009.0   697.0     57704.0                 12.1

# %%
mortality_df.dtypes

# %%
# t test to deterimine if black rate by urban/rural is significant
#(t_stat, p) = ttest_ind(urban["black rate"], rural["black rate"], equal_var=False)
#print(t_stat)
#print(np.float64(p).astype(str))
#if p < 0.05:
    #print("The differences between the urban and rural are significant.")
#else:
    #print("The differences between urban and rural are due to chance.")
