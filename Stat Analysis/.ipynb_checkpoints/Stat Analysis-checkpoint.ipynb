# %%
#Import Dependencies
import pandas as pd
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %%
#Import Wonder Data, and add to DataFrame - 3106 rows with pertinent data in CSV
mortality_df = pd.read_csv('2016Mortality.txt', sep="\t")
mortality_df = mortality_df.head(3105)

# %%
#Transform DataFrame to show columns of interest - remove crude rate and notes, divide deaths/population per 1000
mortality_df = mortality_df[['County', 'County Code', 'Deaths', 'Population']]
mortality_df['Death Rate per 1000'] = (mortality_df['Deaths']/mortality_df['Population'] * 1000).round(1)
mortality_df['County Code'] = mortality_df['County Code'].astype(int)
mortality_df.head()
# Out:
#                County  County Code  Deaths  Population  Death Rate per 1000
# 0  Autauga County, AL         1001   520.0     55416.0                  9.4
# 1  Baldwin County, AL         1003  1974.0    208563.0                  9.5
# 2  Barbour County, AL         1005   256.0     25965.0                  9.9
# 3     Bibb County, AL         1007   239.0     22643.0                 10.6
# 4   Blount County, AL         1009   697.0     57704.0                 12.1

# %%
#Import SVI CSV
svi_df = pd.read_csv('SVI2016_US_COUNTY.csv')
svi_df.head()
# Out:
#    FID  ST    STATE ST_ABBR    COUNTY  FIPS                  LOCATION  \
# 0    0   1  ALABAMA      AL   Autauga  1001   Autauga County, Alabama
# 1    1   1  ALABAMA      AL    Blount  1009    Blount County, Alabama
# 2    2   1  ALABAMA      AL  Chambers  1017  Chambers County, Alabama
# 3    3   1  ALABAMA      AL    Coffee  1031    Coffee County, Alabama
# 4    4   1  ALABAMA      AL   Colbert  1033   Colbert County, Alabama
#
#     AREA_SQMI  E_TOTPOP  M_TOTPOP    ...     F_CROWD  F_NOVEH  F_GROUPQ  \
# 0  594.446120     55049         0    ...           0        0         0
# 1  644.806508     57704         0    ...           0        0         0
# 2  596.531112     34018         0    ...           0        0         0
# 3  678.985652     50991         0    ...           0        0         0
# 4  592.619664     54377         0    ...           0        0         0
#
#    F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP
# 0         0        0       4852        649         8.9         1.2     40854
# 1         0        0       6388        740        11.2         1.3     42597
# 2         0        0       3979        544        11.8         1.6     27940
# 3         0        0       5253        464        10.7         0.9     47236
# 4         0        0       4932        458         9.1         0.8     56227
#
# [5 rows x 124 columns]

# %%
#Merge Mortality and SVI on County Code - Inner join for statistical analysis
merged_df = pd.merge(mortality_df, svi_df, how='inner', left_on='County Code', right_on='FIPS')
merged_df.head()
# Out:
#                County  County Code  Deaths  Population  Death Rate per 1000  \
# 0  Autauga County, AL         1001   520.0     55416.0                  9.4
# 1  Baldwin County, AL         1003  1974.0    208563.0                  9.5
# 2  Barbour County, AL         1005   256.0     25965.0                  9.9
# 3     Bibb County, AL         1007   239.0     22643.0                 10.6
# 4   Blount County, AL         1009   697.0     57704.0                 12.1
#
#     FID  ST    STATE ST_ABBR   COUNTY    ...     F_CROWD F_NOVEH  F_GROUPQ  \
# 0     0   1  ALABAMA      AL  Autauga    ...           0       0         0
# 1  1341   1  ALABAMA      AL  Baldwin    ...           0       0         0
# 2  3074   1  ALABAMA      AL  Barbour    ...           0       0         1
# 3  2113   1  ALABAMA      AL     Bibb    ...           0       0         1
# 4     1   1  ALABAMA      AL   Blount    ...           0       0         0
#
#    F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP
# 0         0        0       4852        649         8.9         1.2     40854
# 1         1        1      23255       1817        11.8         0.9    197683
# 2         2        8       3079        385        13.0         1.6     27321
# 3         2        2       1859        400         9.0         1.9     18756
# 4         0        0       6388        740        11.2         1.3     42597
#
# [5 rows x 129 columns]

# %%
#Perform Spearman (assumes not normal distribution) correlation to determine if relationship between mortality, SVI index
correlations = {}
columns = merged_df.columns.tolist()

for column in columns:
    correlations[column] = spearmanr(merged_df['Death Rate per 1000'], merged_df[column])
# Out:
# /Users/hannah/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
#Add correlation values to DataFrame, sort values
result = pd.DataFrame.from_dict(correlations, orient='index')
result.columns = ['SCC', 'p-value']
result.sort_index()
sorted_df = result.sort_values(by=['SCC'])
sorted_df
# Out:
#                           SCC        p-value
# E_LIMENG            -0.535116  1.808915e-229
# M_LIMENG            -0.501235  4.236370e-197
# E_MINRTY            -0.461334  2.222176e-163
# E_CROWD             -0.455775  5.005209e-159
# E_AGE17             -0.453982  1.218931e-157
# M_MUNIT             -0.449123  6.340737e-154
# M_CROWD             -0.444777  1.188585e-150
# EPL_LIMENG          -0.442789  3.604155e-149
# EP_LIMENG           -0.442527  5.639028e-149
# E_MUNIT             -0.439673  7.231035e-147
# M_UNINSUR           -0.435791  4.942847e-144
# Population          -0.432458  1.254096e-141
# E_DAYPOP            -0.431726  4.198999e-141
# E_TOTPOP            -0.428098  1.597919e-138
# EPL_MUNIT           -0.426852  1.209159e-137
# EP_MUNIT            -0.426400  2.515120e-137
# RPL_THEME3          -0.411751  2.789490e-127
# SPL_THEME3          -0.411745  2.815692e-127
# E_UNINSUR           -0.406540  7.937585e-124
# M_SNGPNT            -0.404844  1.025380e-122
# E_HH                -0.399021  5.976734e-119
# E_SNGPNT            -0.394755  3.073111e-116
# M_UNEMP             -0.389147  9.801950e-113
# E_HU                -0.384482  7.153034e-110
# E_UNEMP             -0.375269  2.361396e-104
# M_POV               -0.373335  3.229313e-103
# E_GROUPQ            -0.373269  3.531188e-103
# M_GROUPQ            -0.366946   1.610181e-99
# M_MINRTY            -0.363350   1.784668e-97
# E_PCI               -0.362047   9.691758e-97
# ...                       ...            ...
# EPL_NOHSDP           0.255820   1.478817e-47
# EP_NOHSDP            0.255820   1.478817e-47
# MP_AGE17             0.278409   2.407593e-56
# EPL_POV              0.293032   1.707168e-62
# EP_POV               0.293032   1.707168e-62
# MP_PCI               0.295668   1.213729e-63
# M_PCI                0.295668   1.213729e-63
# F_AGE65              0.306885   1.154982e-68
# EPL_MOBILE           0.314918   2.127704e-72
# EP_MOBILE            0.314918   2.127704e-72
# F_DISABL             0.314961   2.029712e-72
# SPL_THEME1           0.316768   2.827587e-73
# RPL_THEME1           0.316771   2.816587e-73
# MP_UNINSUR           0.328984   3.195317e-79
# MP_SNGPNT            0.332236   7.493456e-81
# MP_GROUPQ            0.354548   1.402933e-92
# EPL_PCI              0.362047   9.691758e-97
# MP_MOBILE            0.380010  3.592433e-107
# MP_NOHSDP            0.408409  4.655217e-125
# MP_NOVEH             0.413370  2.288355e-128
# MP_POV               0.418229  1.161173e-131
# MP_UNEMP             0.434018  9.473216e-143
# MP_DISABL            0.478592  2.039287e-177
# SPL_THEME2           0.490251  2.292550e-187
# RPL_THEME2           0.490266  2.224223e-187
# EPL_DISABL           0.651990   0.000000e+00
# EP_DISABL            0.651990   0.000000e+00
# EPL_AGE65            0.700513   0.000000e+00
# EP_AGE65             0.700513   0.000000e+00
# Death Rate per 1000  1.000000   0.000000e+00
#
# [129 rows x 2 columns]

# %%
#Perform Pearson correlation to test for stronger relationships, need integer columns only

correlations_p = {}
columns_p = merged_df.columns[13:129].tolist()
for column_p in columns_p:
    correlations_p[column_p] = pearsonr(merged_df['Death Rate per 1000'], merged_df[column_p])
result_p = pd.DataFrame.from_dict(correlations_p, orient='index')
result_p.columns = ['PCC', 'p-value']
sorted_p = result_p.sort_values(by=['PCC'])
sorted_p
# Out:
#                  PCC        p-value
# EPL_LIMENG -0.434319  5.742127e-143
# EP_MUNIT   -0.432810  7.007387e-142
# EPL_MUNIT  -0.413875  1.046615e-128
# SPL_THEME3 -0.411071  7.941810e-127
# RPL_THEME3 -0.404938  8.900245e-123
# M_MUNIT    -0.401528  1.460614e-120
# M_SNGPNT   -0.399526  2.835453e-119
# M_UNINSUR  -0.393110  3.329490e-115
# M_CROWD    -0.389822  3.741118e-113
# M_UNEMP    -0.381762  3.176213e-108
# EP_PCI     -0.377193  1.718669e-105
# E_PCI      -0.377193  1.718669e-105
# M_LIMENG   -0.375529  1.659522e-104
# EP_LIMENG  -0.375258  2.396596e-104
# M_POV      -0.365320   1.364272e-98
# F_MUNIT    -0.359065   4.506625e-95
# M_DISABL   -0.358440   1.002913e-94
# M_GROUPQ   -0.350310   2.810088e-90
# M_NOHSDP   -0.345104   1.690960e-87
# M_HH       -0.330834   3.800912e-80
# M_NOVEH    -0.325820   1.178228e-77
# F_AGE17    -0.324394   5.909001e-77
# EP_AGE17   -0.321553   1.427800e-75
# EPL_AGE17  -0.315397   1.263371e-72
# M_HU       -0.314527   3.254971e-72
# M_MINRTY   -0.313491   9.995522e-72
# F_LIMENG   -0.305157   7.094259e-68
# EPL_MINRTY -0.295748   1.120160e-63
# E_GROUPQ   -0.289144   8.007244e-61
# F_THEME3   -0.278877   1.550538e-56
# ...              ...            ...
# RPL_THEMES  0.152952   1.060773e-17
# EPL_UNEMP   0.164148   3.493630e-20
# EPL_NOVEH   0.176019   5.169406e-23
# EP_NOHSDP   0.176488   3.957438e-23
# MP_PCI      0.178282   1.414487e-23
# M_PCI       0.178282   1.414487e-23
# MP_UNINSUR  0.234080   6.895090e-40
# EPL_NOHSDP  0.237970   3.326099e-41
# EP_POV      0.247403   1.695741e-44
# EP_MOBILE   0.264662   6.781333e-51
# EPL_POV     0.272197   7.648184e-54
# MP_SNGPNT   0.284555   6.946679e-59
# RPL_THEME1  0.295112   2.126553e-63
# SPL_THEME1  0.295463   1.493213e-63
# EPL_MOBILE  0.296523   5.120287e-64
# MP_MOBILE   0.308403   2.320887e-69
# F_DISABL    0.317231   1.702183e-73
# MP_NOHSDP   0.327755   1.304655e-78
# F_AGE65     0.333320   2.122298e-81
# MP_NOVEH    0.337197   2.238326e-83
# EPL_PCI     0.341481   1.353760e-85
# MP_UNEMP    0.344121   5.587219e-87
# MP_POV      0.358230   1.311791e-94
# MP_DISABL   0.416183  2.876158e-130
# RPL_THEME2  0.469714  4.281086e-170
# SPL_THEME2  0.499618  1.209694e-195
# EP_DISABL   0.622342   0.000000e+00
# EPL_DISABL  0.630955   0.000000e+00
# EP_AGE65    0.679803   0.000000e+00
# EPL_AGE65   0.693704   0.000000e+00
#
# [116 rows x 2 columns]

# %%
#Import life expectancy DF
life_df = pd.read_csv('lifemedicare.csv')
life_df.head()
# Out:
#    Unnamed: 0                 Location  FIPS  Life Expectancy  \
# 0           0  Autauga County, Alabama  1001            75.67
# 1           1  Baldwin County, Alabama  1003            78.08
# 2           2  Barbour County, Alabama  1005            75.42
# 3           3     Bibb County, Alabama  1007            73.97
# 4           4   Blount County, Alabama  1009            76.16
#
#          County name Total per enrollee (age, sex, race adjusted)  \
# 0  AL-Autauga County                                       8,848
# 1  AL-Baldwin County                                       8,427
# 2  AL-Barbour County                                       8,979
# 3     AL-Bibb County                                       9,550
# 4   AL-Blount County                                       9,860
#
#   Total per enrollee (age, sex, race, price adjusted)
# 0                                            10,413
# 1                                             9,883
# 2                                            10,704
# 3                                            10,860
# 4                                            11,179

# %%
#Merge life expectancy and SVI on County Code - Inner join for statistical analysis
merged_df2 = pd.merge(life_df, svi_df, how='inner', left_on='FIPS', right_on='FIPS')
merged_df2.head()
# Out:
#    Unnamed: 0                 Location  FIPS  Life Expectancy  \
# 0           0  Autauga County, Alabama  1001            75.67
# 1           1  Baldwin County, Alabama  1003            78.08
# 2           2  Barbour County, Alabama  1005            75.42
# 3           3     Bibb County, Alabama  1007            73.97
# 4           4   Blount County, Alabama  1009            76.16
#
#          County name Total per enrollee (age, sex, race adjusted)  \
# 0  AL-Autauga County                                       8,848
# 1  AL-Baldwin County                                       8,427
# 2  AL-Barbour County                                       8,979
# 3     AL-Bibb County                                       9,550
# 4   AL-Blount County                                       9,860
#
#   Total per enrollee (age, sex, race, price adjusted)   FID  ST    STATE  \
# 0                                            10,413       0   1  ALABAMA
# 1                                             9,883    1341   1  ALABAMA
# 2                                            10,704    3074   1  ALABAMA
# 3                                            10,860    2113   1  ALABAMA
# 4                                            11,179       1   1  ALABAMA
#
#      ...    F_CROWD F_NOVEH F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  \
# 0    ...          0       0        0         0        0       4852        649
# 1    ...          0       0        0         1        1      23255       1817
# 2    ...          0       0        1         2        8       3079        385
# 3    ...          0       0        1         2        2       1859        400
# 4    ...          0       0        0         0        0       6388        740
#
#    EP_UNINSUR  MP_UNINSUR  E_DAYPOP
# 0         8.9         1.2     40854
# 1        11.8         0.9    197683
# 2        13.0         1.6     27321
# 3         9.0         1.9     18756
# 4        11.2         1.3     42597
#
# [5 rows x 130 columns]

# %%
#Perform Spearman correlation to determine if relationship between life expectancy, SVI index
correlations_life = {}
columns_life = merged_df2.columns[12:130].tolist()

for column in columns_life:
    correlations_life[column] = spearmanr(merged_df2['Life Expectancy'], merged_df2[column])
result_life = pd.DataFrame.from_dict(correlations_life, orient='index')
result_life.columns = ['SCC', 'p-value']
result_life.sort_index()
sorted_life_df = result_life.sort_values(by=['SCC'])
sorted_life_df
# Out:
# /Users/hannah/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
#                  SCC        p-value
# RPL_THEME1 -0.773194   0.000000e+00
# SPL_THEME1 -0.773187   0.000000e+00
# EPL_PCI    -0.702873   0.000000e+00
# SPL_THEMES -0.696074   0.000000e+00
# RPL_THEMES -0.696073   0.000000e+00
# EPL_NOHSDP -0.695788   0.000000e+00
# EP_NOHSDP  -0.695788   0.000000e+00
# EPL_POV    -0.693060   0.000000e+00
# EP_POV     -0.693060   0.000000e+00
# RPL_THEME2 -0.634747   0.000000e+00
# SPL_THEME2 -0.634746   0.000000e+00
# EP_DISABL  -0.615436   0.000000e+00
# EPL_DISABL -0.615436   0.000000e+00
# EP_MOBILE  -0.597332  2.982648e-303
# EPL_MOBILE -0.597332  2.982648e-303
# EPL_UNEMP  -0.557597  3.127387e-256
# EP_UNEMP   -0.557597  3.127387e-256
# EP_UNINSUR -0.503590  1.031971e-201
# MP_UNEMP   -0.459059  1.350696e-163
# EP_SNGPNT  -0.453833  1.756922e-159
# EPL_SNGPNT -0.453788  1.903939e-159
# F_THEME1   -0.443301  2.091280e-151
# MP_MOBILE  -0.424064  2.259311e-137
# EP_NOVEH   -0.411567  9.859336e-129
# EPL_NOVEH  -0.411567  9.859336e-129
# MP_NOHSDP  -0.394830  1.005607e-117
# MP_POV     -0.389451  2.555763e-114
# F_POV      -0.366819  1.130248e-100
# RPL_THEME4 -0.363033   1.703875e-98
# SPL_THEME4 -0.363028   1.714074e-98
# ...              ...            ...
# E_SNGPNT    0.018072   3.112164e-01
# M_AGE65     0.019561   2.730320e-01
# M_LIMENG    0.045603   1.057233e-02
# M_GROUPQ    0.056116   1.651183e-03
# E_GROUPQ    0.063948   3.348046e-04
# E_AGE17     0.073318   3.894648e-05
# EPL_AGE65   0.075681   2.170595e-05
# EP_AGE65    0.075681   2.170595e-05
# E_DAYPOP    0.087003   1.038829e-06
# E_TOTPOP    0.089047   5.752478e-07
# E_HH        0.103827   5.433338e-09
# E_AGE65     0.105882   2.690692e-09
# E_HU        0.106414   2.238252e-09
# F_LIMENG    0.115445   8.568907e-11
# M_TOTPOP    0.120490   1.236247e-11
# M_MINRTY    0.135715   2.177901e-14
# M_HU        0.138350   6.730938e-15
# EP_LIMENG   0.145381   2.624737e-16
# EPL_LIMENG  0.145600   2.366826e-16
# MP_MUNIT    0.148592   5.649537e-17
# E_LIMENG    0.151435   1.409566e-17
# F_AGE65     0.155710   1.660923e-18
# AREA_SQMI   0.189390   9.256070e-27
# M_MUNIT     0.201753   3.242923e-30
# F_MUNIT     0.245675   2.056323e-44
# E_MUNIT     0.254474   1.251012e-47
# EP_MUNIT    0.375720  6.543925e-106
# EPL_MUNIT   0.375950  4.767822e-106
# E_PCI       0.702873   0.000000e+00
# EP_PCI      0.702873   0.000000e+00
#
# [118 rows x 2 columns]

# %%
#Perform Pearson correlation to determine if relationship between life expectancy, SVI index
correlations_life_p = {}
columns_life_p = merged_df3.columns[13:130].tolist()

for column in columns_life_p:
    correlations_life_p[column] = pearsonr(merged_df3['Life Expectancy'], merged_df3[column])
result_life_p = pd.DataFrame.from_dict(correlations_life_p, orient='index')
result_life_p.columns = ['PCC', 'p-value']
result_life_p.sort_index()
sorted_life_p = result_life_p.sort_values(by=['PCC'])
sorted_life_p
# Out:
#                  PCC        p-value
# SPL_THEME1 -0.764425   0.000000e+00
# RPL_THEME1 -0.762146   0.000000e+00
# EPL_PCI    -0.701032   0.000000e+00
# EPL_POV    -0.689713   0.000000e+00
# EP_POV     -0.685514   0.000000e+00
# RPL_THEMES -0.683695   0.000000e+00
# EPL_NOHSDP -0.680065   0.000000e+00
# SPL_THEMES -0.674783   0.000000e+00
# RPL_THEME2 -0.620507   0.000000e+00
# SPL_THEME2 -0.614892   0.000000e+00
# EP_NOHSDP  -0.608046  4.341077e-317
# EP_DISABL  -0.599995  1.212732e-306
# EPL_DISABL -0.595887  1.997187e-301
# EPL_MOBILE -0.582114  1.786172e-284
# EP_MOBILE  -0.567033  8.065374e-267
# EP_UNEMP   -0.559170  5.668896e-258
# EPL_UNEMP  -0.555321  9.970393e-254
# F_THEME1   -0.479048  5.211495e-180
# EP_SNGPNT  -0.472334  2.253409e-174
# EPL_SNGPNT -0.453975  1.361269e-159
# EPL_NOVEH  -0.426886  2.247880e-139
# EP_UNINSUR -0.422133  5.171254e-136
# F_POV      -0.420131  1.296741e-134
# F_PCI      -0.390178  8.928046e-115
# SPL_THEME4 -0.378132  2.330848e-107
# RPL_THEME4 -0.366234  2.463456e-100
# F_TOTAL    -0.362521   3.337350e-98
# F_UNEMP    -0.349992   3.240190e-91
# F_MOBILE   -0.342003   6.354885e-87
# MP_MOBILE  -0.332609   4.908883e-82
# ...              ...            ...
# M_NOVEH     0.128193   5.489911e-13
# E_SNGPNT    0.128370   5.098172e-13
# E_UNEMP     0.128510   4.809984e-13
# F_LIMENG    0.129555   3.102263e-13
# E_DISABL    0.131493   1.363424e-13
# M_UNEMP     0.133009   7.103851e-14
# M_HH        0.134208   4.219226e-14
# M_UNINSUR   0.139870   3.384092e-15
# E_MUNIT     0.141088   1.940429e-15
# M_SNGPNT    0.143927   5.203488e-16
# F_AGE65     0.152466   8.462649e-18
# M_HU        0.154593   2.921023e-18
# E_GROUPQ    0.158131   4.815916e-19
# M_CROWD     0.159997   1.830269e-19
# E_AGE17     0.160295   1.566055e-19
# E_DAYPOP    0.162199   5.752762e-20
# EP_LIMENG   0.163957   2.257981e-20
# E_TOTPOP    0.166229   6.637295e-21
# E_HU        0.167462   3.391099e-21
# E_HH        0.169180   1.318499e-21
# EPL_LIMENG  0.169951   8.604142e-22
# E_AGE65     0.176881   1.690104e-23
# M_LIMENG    0.211189   5.199720e-33
# M_MINRTY    0.216897   9.093536e-35
# M_MUNIT     0.245187   3.076575e-44
# F_MUNIT     0.250839   2.762372e-46
# EP_MUNIT    0.345172   1.304780e-88
# EPL_MUNIT   0.368544  1.124732e-101
# E_PCI       0.671904   0.000000e+00
# EP_PCI      0.671904   0.000000e+00
#
# [117 rows x 2 columns]

# %%
#Take sample of 500 random counties, export to CSV for visualization test
random_counties_life = merged_df2.sample(n=500, random_state=1)
random_counties_life.head()
random_counties_life.to_csv('randomcounties_life.csv')
