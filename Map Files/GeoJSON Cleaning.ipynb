# %%
import json
import geojson
from pprint import pprint
import pandas as pd

# %%
usgeojson = {
    "type": "FeatureCollection",
    "features": []
}

# %%
death = pd.read_csv("AllDeath.csv")
death['FIPS'] = death['FIPS'].apply(lambda x: '{0:0>5}'.format(x))
death = death.fillna("Not Available")
death.head(15)
# Out:
#     Unnamed: 0   FID   ST    STATE ST_ABBR      COUNTY   FIPS  \
# 0            0   0.0  1.0  ALABAMA      AL     Autauga  01001
# 1            1   1.0  1.0  ALABAMA      AL      Blount  01009
# 2            2   2.0  1.0  ALABAMA      AL    Chambers  01017
# 3            3   3.0  1.0  ALABAMA      AL      Coffee  01031
# 4            4   4.0  1.0  ALABAMA      AL     Colbert  01033
# 5            5   5.0  1.0  ALABAMA      AL   Covington  01039
# 6            6   6.0  1.0  ALABAMA      AL     Cullman  01043
# 7            7   7.0  1.0  ALABAMA      AL        Dale  01045
# 8            8   8.0  1.0  ALABAMA      AL      Elmore  01051
# 9            9   9.0  1.0  ALABAMA      AL      Etowah  01055
# 10          10  10.0  1.0  ALABAMA      AL       Henry  01067
# 11          11  11.0  1.0  ALABAMA      AL     Houston  01069
# 12          12  12.0  1.0  ALABAMA      AL     Jackson  01071
# 13          13  13.0  1.0  ALABAMA      AL  Lauderdale  01077
# 14          14  14.0  1.0  ALABAMA      AL    Lawrence  01079
#
#                       LOCATION    AREA_SQMI  E_TOTPOP  \
# 0      Autauga County, Alabama   594.446120   55049.0
# 1       Blount County, Alabama   644.806508   57704.0
# 2     Chambers County, Alabama   596.531112   34018.0
# 3       Coffee County, Alabama   678.985652   50991.0
# 4      Colbert County, Alabama   592.619664   54377.0
# 5    Covington County, Alabama  1030.455836   37729.0
# 6      Cullman County, Alabama   734.897489   81316.0
# 7         Dale County, Alabama   561.125964   49607.0
# 8       Elmore County, Alabama   618.487734   80957.0
# 9       Etowah County, Alabama   535.283927  103363.0
# 10       Henry County, Alabama   561.750076   17187.0
# 11     Houston County, Alabama   579.866113  103891.0
# 12     Jackson County, Alabama  1077.866978   52608.0
# 13  Lauderdale County, Alabama   667.699347   92641.0
# 14    Lawrence County, Alabama   690.677152   33433.0
#
#                            ...                           LowerResp_Death_Rate  \
# 0                          ...                                       0.667677
# 1                          ...                                        1.09178
# 2                          ...                                       0.945543
# 3                          ...                                       0.663725
# 4                          ...                                        1.03291
# 5                          ...                                        1.28144
# 6                          ...                                        1.00641
# 7                          ...                                       0.792264
# 8                          ...                                       0.562354
# 9                          ...                                        1.17975
# 10                         ...                                  Not Available
# 11                         ...                                         0.4709
# 12                         ...                                        1.34259
# 13                         ...                                       0.758249
# 14                         ...                                       0.721935
#
#     Stroke_Deaths  Stroke_Death_Rate  Suicide_Deaths  Suicide_Death_Rate  \
# 0              36           0.649632              14            0.252635
# 1              36           0.623874              11            0.190628
# 2              27           0.797802              15            0.443223
# 3              26           0.507555              10            0.195213
# 4              38             0.7009   Not Available       Not Available
# 5              30           0.800897   Not Available       Not Available
# 6              54           0.654776              19            0.230384
# 7              29            0.58912   Not Available       Not Available
# 8              44           0.537904              21            0.256727
# 9              58           0.565501              17             0.16575
# 10             14           0.815661   Not Available       Not Available
# 11             53           0.509341              10           0.0961021
# 12             40           0.767195              14            0.268518
# 13             65           0.704088              20            0.216642
# 14             21           0.631693   Not Available       Not Available
#
#                       Location  Life Expectancy           County name  \
# 0      Autauga County, Alabama            75.67     AL-Autauga County
# 1       Blount County, Alabama            76.16      AL-Blount County
# 2     Chambers County, Alabama            74.06    AL-Chambers County
# 3       Coffee County, Alabama            76.48      AL-Coffee County
# 4      Colbert County, Alabama            75.07     AL-Colbert County
# 5    Covington County, Alabama            75.15   AL-Covington County
# 6      Cullman County, Alabama            75.31     AL-Cullman County
# 7         Dale County, Alabama            76.26        AL-Dale County
# 8       Elmore County, Alabama            75.93      AL-Elmore County
# 9       Etowah County, Alabama            73.85      AL-Etowah County
# 10       Henry County, Alabama            75.97       AL-Henry County
# 11     Houston County, Alabama            76.81     AL-Houston County
# 12     Jackson County, Alabama            74.13     AL-Jackson County
# 13  Lauderdale County, Alabama            76.50  AL-Lauderdale County
# 14    Lawrence County, Alabama            74.33    AL-Lawrence County
#
#     Total per enrollee (age, sex, race adjusted)  \
# 0                                         8,848
# 1                                         9,860
# 2                                         8,033
# 3                                         8,560
# 4                                         9,063
# 5                                         9,825
# 6                                         9,488
# 7                                         8,960
# 8                                         9,185
# 9                                        10,845
# 10                                        8,658
# 11                                        8,764
# 12                                       10,024
# 13                                        7,983
# 14                                        9,456
#
#     Total per enrollee (age, sex, race, price adjusted)
# 0                                             10,413
# 1                                             11,179
# 2                                              9,505
# 3                                             10,256
# 4                                             11,110
# 5                                             11,830
# 6                                             10,548
# 7                                             10,873
# 8                                             10,769
# 9                                             12,899
# 10                                            10,502
# 11                                            10,632
# 12                                            11,504
# 13                                             9,753
# 14                                            10,960
#
# [15 rows x 116 columns]

# %%
states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
"District_of_Columbia", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas",
"Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri",
"Montana", "Nebraska", "Nevada", "New_Hampshire", "New_Jersey", "New_Mexico", "New_York", "North_Carolina",
"North_Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode_Island", "South_Carolina", "South_Dakota",
"Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West_Virginia", "Wisconsin", "Wyoming"]

# %%
for state in states:
    with open(f'GeoJSON/{state}.geo.json') as f:
        features = json.load(f)["features"]
        for foo in features:
            try:
                fips = foo['properties']["FIPS"]
                deathdata = death.loc[death["FIPS"] == fips, :]
                deathdict = deathdata.to_dict(orient = 'records')[0]
                foo["properties"] = deathdict
                usgeojson["features"].append(foo)
            except:
                print(f'An error occured for FIPS #: {fips}')
# Out:
# An error occured for FIPS #: 02270
# An error occured for FIPS #: 02280
# An error occured for FIPS #: 02201
# An error occured for FIPS #: 02232
# An error occured for FIPS #: 46113
# An error occured for FIPS #: 51515

# %%
with open('us.geo.json', 'w') as fp:
    geojson.dump(usgeojson, fp)
